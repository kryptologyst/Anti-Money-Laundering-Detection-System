# %% [markdown]
# # AML Detection System Analysis
#
# ## ⚠️ IMPORTANT DISCLAIMER
#
# **This is a research and educational demonstration only.**
#
# - NOT FOR REAL-WORLD AML COMPLIANCE OR REGULATORY REPORTING
# - Results should NOT be used for making financial decisions
# - This is NOT investment advice
# - Backtests are hypothetical and do not guarantee future performance
#
# ---
#
# ## Overview
#
# This notebook provides a comprehensive analysis of the AML Detection System, including:
#
# 1. **Data Exploration**: Understanding the synthetic AML dataset
# 2. **Feature Analysis**: Examining engineered features
# 3. **Model Training**: Training multiple AML detection models
# 4. **Model Evaluation**: Comprehensive evaluation with AML-specific metrics
# 5. **Explainability**: Understanding model decisions with SHAP
# 6. **Network Analysis**: Analyzing customer relationship networks
#
# Let's start by importing the necessary libraries and loading the data.
